# %% [markdown]
# ## Overview
#
# FLIGHT DATA ANALYSIS..!!

# %%
dbutils.fs.unmount("/mnt/flight_data")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/flight_data has been unmounted.
# Out[68]: True</div>

# %%
import urllib

ACCESS_KEY = "AKIA2YMHHRUQ5QNXVQF5"
SECRET_KEY = "3YTBPU5YTA6jJTVj2oFp3XDnw0EweYzJgF/r21BE"
ENCODED_SECRET_KEY = SECRET_KEY.replace("/", "%2F")
AWS_BUCKET_NAME = "airplane-data-bigdata"
MOUNT_NAME = "flight_data"

dbutils.fs.mount("s3a://%s:%s@%s" % (ACCESS_KEY, ENCODED_SECRET_KEY, AWS_BUCKET_NAME), "/mnt/%s" % MOUNT_NAME)
display(dbutils.fs.ls("/mnt/%s" % MOUNT_NAME))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/flight_data/airplane_data/</td><td>airplane_data/</td><td>0</td></tr></tbody></table></div>

# %%
display(dbutils.fs.ls("/mnt/flight_data/airplane_data"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/flight_data/airplane_data/airOT201201.csv</td><td>airOT201201.csv</td><td>108491129</td></tr><tr><td>dbfs:/mnt/flight_data/airplane_data/airOT201202.csv</td><td>airOT201202.csv</td><td>103650423</td></tr><tr><td>dbfs:/mnt/flight_data/airplane_data/airOT201203.csv</td><td>airOT201203.csv</td><td>116715440</td></tr><tr><td>dbfs:/mnt/flight_data/airplane_data/airOT201204.csv</td><td>airOT201204.csv</td><td>112621462</td></tr><tr><td>dbfs:/mnt/flight_data/airplane_data/airOT201205.csv</td><td>airOT201205.csv</td><td>115920355</td></tr><tr><td>dbfs:/mnt/flight_data/airplane_data/airOT201206.csv</td><td>airOT201206.csv</td><td>117982747</td></tr><tr><td>dbfs:/mnt/flight_data/airplane_data/airOT201207.csv</td><td>airOT201207.csv</td><td>122492957</td></tr><tr><td>dbfs:/mnt/flight_data/airplane_data/airOT201208.csv</td><td>airOT201208.csv</td><td>121168966</td></tr><tr><td>dbfs:/mnt/flight_data/airplane_data/airOT201209.csv</td><td>airOT201209.csv</td><td>109648233</td></tr><tr><td>dbfs:/mnt/flight_data/airplane_data/airOT201210.csv</td><td>airOT201210.csv</td><td>115129701</td></tr><tr><td>dbfs:/mnt/flight_data/airplane_data/airOT201211.csv</td><td>airOT201211.csv</td><td>109298312</td></tr><tr><td>dbfs:/mnt/flight_data/airplane_data/airOT201212.csv</td><td>airOT201212.csv</td><td>111452061</td></tr></tbody></table></div>

# %%
from functools import reduce

import string
all_files=[]
file_path = dbutils.fs.ls("/mnt/flight_data/airplane_data")
for i in file_path:
  s = i.path
  all_files.append(s[5:len(s)])
  
df = reduce(lambda x,y: x.unionAll(y), 
            [sqlContext.read.format('com.databricks.spark.csv')
                       .load(f, header="true", inferSchema="true") 
             for f in all_files])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YEAR</th><th>MONTH</th><th>DAY_OF_MONTH</th><th>DAY_OF_WEEK</th><th>FL_DATE</th><th>UNIQUE_CARRIER</th><th>TAIL_NUM</th><th>FL_NUM</th><th>ORIGIN_AIRPORT_ID</th><th>ORIGIN</th><th>ORIGIN_STATE_ABR</th><th>DEST_AIRPORT_ID</th><th>DEST</th><th>DEST_STATE_ABR</th><th>CRS_DEP_TIME</th><th>DEP_TIME</th><th>DEP_DELAY</th><th>DEP_DELAY_NEW</th><th>DEP_DEL15</th><th>DEP_DELAY_GROUP</th><th>TAXI_OUT</th><th>WHEELS_OFF</th><th>WHEELS_ON</th><th>TAXI_IN</th><th>CRS_ARR_TIME</th><th>ARR_TIME</th><th>ARR_DELAY</th><th>ARR_DELAY_NEW</th><th>ARR_DEL15</th><th>ARR_DELAY_GROUP</th><th>CANCELLED</th><th>CANCELLATION_CODE</th><th>DIVERTED</th><th>CRS_ELAPSED_TIME</th><th>ACTUAL_ELAPSED_TIME</th><th>AIR_TIME</th><th>FLIGHTS</th><th>DISTANCE</th><th>DISTANCE_GROUP</th><th>CARRIER_DELAY</th><th>WEATHER_DELAY</th><th>NAS_DELAY</th><th>SECURITY_DELAY</th><th>LATE_AIRCRAFT_DELAY</th><th>_c44</th></tr></thead><tbody><tr><td>2012</td><td>1</td><td>1</td><td>7</td><td>2012-01-01T00:00:00.000+0000</td><td>AA</td><td>N325AA</td><td>1</td><td>12478</td><td>JFK</td><td>NY</td><td>12892</td><td>LAX</td><td>CA</td><td>900</td><td>855</td><td>-5.0</td><td>0.0</td><td>0.0</td><td>-1</td><td>13.0</td><td>908</td><td>1138</td><td>4.0</td><td>1225</td><td>1142</td><td>-43.0</td><td>0.0</td><td>0.0</td><td>-2</td><td>0.0</td><td>null</td><td>0.0</td><td>385.0</td><td>347.0</td><td>330.0</td><td>1.0</td><td>2475.0</td><td>10</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2012</td><td>1</td><td>2</td><td>1</td><td>2012-01-02T00:00:00.000+0000</td><td>AA</td><td>N319AA</td><td>1</td><td>12478</td><td>JFK</td><td>NY</td><td>12892</td><td>LAX</td><td>CA</td><td>900</td><td>921</td><td>21.0</td><td>21.0</td><td>1.0</td><td>1</td><td>13.0</td><td>934</td><td>1159</td><td>11.0</td><td>1225</td><td>1210</td><td>-15.0</td><td>0.0</td><td>0.0</td><td>-1</td><td>0.0</td><td>null</td><td>0.0</td><td>385.0</td><td>349.0</td><td>325.0</td><td>1.0</td><td>2475.0</td><td>10</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2012</td><td>1</td><td>3</td><td>2</td><td>2012-01-03T00:00:00.000+0000</td><td>AA</td><td>N323AA</td><td>1</td><td>12478</td><td>JFK</td><td>NY</td><td>12892</td><td>LAX</td><td>CA</td><td>900</td><td>931</td><td>31.0</td><td>31.0</td><td>1.0</td><td>2</td><td>12.0</td><td>943</td><td>1202</td><td>22.0</td><td>1225</td><td>1224</td><td>-1.0</td><td>0.0</td><td>0.0</td><td>-1</td><td>0.0</td><td>null</td><td>0.0</td><td>385.0</td><td>353.0</td><td>319.0</td><td>1.0</td><td>2475.0</td><td>10</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2012</td><td>1</td><td>4</td><td>3</td><td>2012-01-04T00:00:00.000+0000</td><td>AA</td><td>N320AA</td><td>1</td><td>12478</td><td>JFK</td><td>NY</td><td>12892</td><td>LAX</td><td>CA</td><td>900</td><td>904</td><td>4.0</td><td>4.0</td><td>0.0</td><td>0</td><td>18.0</td><td>922</td><td>1131</td><td>20.0</td><td>1225</td><td>1151</td><td>-34.0</td><td>0.0</td><td>0.0</td><td>-2</td><td>0.0</td><td>null</td><td>0.0</td><td>385.0</td><td>347.0</td><td>309.0</td><td>1.0</td><td>2475.0</td><td>10</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2012</td><td>1</td><td>5</td><td>4</td><td>2012-01-05T00:00:00.000+0000</td><td>AA</td><td>N338AA</td><td>1</td><td>12478</td><td>JFK</td><td>NY</td><td>12892</td><td>LAX</td><td>CA</td><td>900</td><td>858</td><td>-2.0</td><td>0.0</td><td>0.0</td><td>-1</td><td>16.0</td><td>914</td><td>1120</td><td>22.0</td><td>1225</td><td>1142</td><td>-43.0</td><td>0.0</td><td>0.0</td><td>-2</td><td>0.0</td><td>null</td><td>0.0</td><td>385.0</td><td>344.0</td><td>306.0</td><td>1.0</td><td>2475.0</td><td>10</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2012</td><td> ...

# %%
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[96]: 6096762</div>

# %%
df[df['Year'] == 'Year']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[95]: DataFrame[YEAR: int, MONTH: int, DAY_OF_MONTH: int, DAY_OF_WEEK: int, FL_DATE: timestamp, UNIQUE_CARRIER: string, TAIL_NUM: string, FL_NUM: int, ORIGIN_AIRPORT_ID: int, ORIGIN: string, ORIGIN_STATE_ABR: string, DEST_AIRPORT_ID: int, DEST: string, DEST_STATE_ABR: string, CRS_DEP_TIME: int, DEP_TIME: int, DEP_DELAY: double, DEP_DELAY_NEW: double, DEP_DEL15: double, DEP_DELAY_GROUP: int, TAXI_OUT: double, WHEELS_OFF: int, WHEELS_ON: int, TAXI_IN: double, CRS_ARR_TIME: int, ARR_TIME: int, ARR_DELAY: double, ARR_DELAY_NEW: double, ARR_DEL15: double, ARR_DELAY_GROUP: int, CANCELLED: double, CANCELLATION_CODE: string, DIVERTED: double, CRS_ELAPSED_TIME: double, ACTUAL_ELAPSED_TIME: double, AIR_TIME: double, FLIGHTS: double, DISTANCE: double, DISTANCE_GROUP: int, CARRIER_DELAY: double, WEATHER_DELAY: double, NAS_DELAY: double, SECURITY_DELAY: double, LATE_AIRCRAFT_DELAY: double, _c44: string]</div>

# %%
**dont run below this**

# %%
# File location and type
file_location = "{{upload_location}}"
file_type = "{{file_type}}"

# CSV options
infer_schema = "{{infer_schema}}"
first_row_is_header = "{{first_row_is_header}}"
delimiter = "{{delimiter}}"

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)

# %%
# Create a view or table

temp_table_name = "{{file_name}}"

df.createOrReplaceTempView(temp_table_name)

# %%
# %sql

/* Query the created temp table in a SQL cell */

select * from `{{file_name}}`

# %%
# Since this table is registered as a temp view, it will only be available to this notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

permanent_table_name = "{{table_name}}"

# df.write.format("{{table_import_type}}").saveAsTable(permanent_table_name)
