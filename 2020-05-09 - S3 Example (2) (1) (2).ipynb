# %% [markdown]
# ##FINAL PROJECT..!!
#
# **FLIGHT DATA ANALYSIS..!!**

# %%
dbutils.fs.unmount("/mnt/flight_data")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/flight_data has been unmounted.
# Out[1]: True</div>

# %%
import urllib

#CONNECTING WITH AWS IN ORDER TO ACCESS S3 FILES.
ACCESS_KEY = "AKIA2YMHHRUQ5QNXVQF5"
SECRET_KEY = "3YTBPU5YTA6jJTVj2oFp3XDnw0EweYzJgF/r21BE"
ENCODED_SECRET_KEY = SECRET_KEY.replace("/", "%2F")
AWS_BUCKET_NAME = "airplane-data-bigdata"
MOUNT_NAME = "flight_data"

dbutils.fs.mount("s3a://%s:%s@%s" % (ACCESS_KEY, ENCODED_SECRET_KEY, AWS_BUCKET_NAME), "/mnt/%s" % MOUNT_NAME)
display(dbutils.fs.ls("/mnt/%s" % MOUNT_NAME))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/flight_data/airplane_data/</td><td>airplane_data/</td><td>0</td></tr></tbody></table></div>

# %%
#LIST OF FILES 
display(dbutils.fs.ls("/mnt/flight_data/airplane_data"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ##Impact of Global Recession On the Airport Industry..!!
#
# <br>
# When housing prices fell and homeowners began to walk away from their mortgages, the value of mortgage-backed securities held by investment banks declined in 2007–2008, causing several to collapse on the economy of the United States in the years of 2008 and ahead....
#
# source:wikipedia

# %%
#INCLUDES DATA FOR THE 3 YEARS 2007-2008-2009
Impact_Years_df = spark.read.format("csv").option("header", "true").load("/mnt/flight_data/airplane_data/*200[7|8|9]*.csv")

#INCLUDES DATA FOR THE 3 YEARS 2010-2011-2012
After_Impact_df = spark.read.format("csv").option("header", "true").load("/mnt/flight_data/airplane_data/*201[0|1|2]*.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(Impact_Years_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(After_Impact_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
Impact_Years_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: 20915469</div>

# %%
After_Impact_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: 18632160</div>

# %% [markdown]
# The above count queries are taking more time to execute as the whole table is getting traversed,thus there is a need of optimization over these dataframes.

# %%
#Check for the Number of Partitions.
Impact_Years_df.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[45]: 38</div>

# %%
#Check for the Number of Partitions.
After_Impact_df.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[46]: 36</div>

# %% [markdown]
# Above shown are the default Number of Partitions done by the Spark and there is a need to optimize the partition size for the dataframes.

# %%
#setting new repartition value.
Impact_Years_df.repartition(12).createOrReplaceTempView("Impact_Years_view")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#setting new repartition value.
After_Impact_df.repartition(9).createOrReplaceTempView("After_Impact_view")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.catalog.cacheTable('Impact_Years_view')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.catalog.cacheTable('After_Impact_view')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# This cache creation is done once an action query is triggered on the particular table.

# %%
spark.table("Impact_Years_view").count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[52]: 20915469</div>

# %%
spark.table("After_Impact_view").count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[53]: 18632160</div>

# %% [markdown]
# Above count queries will re run long for the first time as the whole table is traversed and new partitions are recreated in memory.

# %%
Impact_Years_final = spark.table("Impact_Years_view")
After_Impacts_Year_final = spark.table("After_Impact_view")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#in order to delete the cached rdd.
#df_view.unpersist()
#sqlContext.uncacheTable("df_view")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#df.registerTempTable('myData')
#df_1.registerTempTable('my_Data2')

# %%
#Number of Flights for the Years 2007,2008,2009.!!
display(spark.sql('select year,count(year) as Number_Flight_rides FROM (select * from Impact_Years_view union all select * from After_Impact_view) GROUP BY year order by year'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>Number_Flight_rides</th></tr></thead><tbody><tr><td>2007</td><td>7455458</td></tr><tr><td>2008</td><td>7009726</td></tr><tr><td>2009</td><td>6450285</td></tr><tr><td>2010</td><td>6450117</td></tr><tr><td>2011</td><td>6085281</td></tr><tr><td>2012</td><td>6096762</td></tr></tbody></table></div>

# %%
spark.conf.get("spark.sql.shuffle.partitions")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[63]: &#39;200&#39;</div>

# %%
spark.conf.set("spark.sql.shuffle.partitions",6)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Number of Flights for the Years 2007,2008,2009.!!
display(spark.sql('select year,count(CANCELLED) FROM my_Data2 where CANCELLED = 1 GROUP BY year'))

# %%
#STATEWISE DISTRIBUTION FOR THE IMPACTED YEARS..!
display(spark.sql('select DEST_STATE_ABR,count(DEST_STATE_ABR) as Frequency_Flights,year from Impact_Years_view group by YEAR,DEST_STATE_ABR ORDER BY count(DEST_STATE_ABR)'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#select(Impact_Years_view("YEAR").cast(IntegerType).as("YEAR"))
display(spark.sql('select distinct CAST(MONTH AS INT),COUNT(CAST(MONTH AS INT)) as NUMBER_OF_FLIGHTS ,CAST(YEAR AS INT) from Impact_Years_view WHERE YEAR IN("2008","2009") GROUP BY CAST(MONTH AS INT),CAST(YEAR AS INT) ORDER BY CAST(YEAR AS INT),CAST(MONTH AS INT)'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Comparing the Trends in the Flights for the Top 5 Airplane Carriers (Based on the 2007 results) .

# %%
sqlContext.sql('select CAST(UNIQUE_CARRIER AS string),count(UNIQUE_CARRIER) from Impact_Years_view where CAST(Year as int) = "2007" group by cast(UNIQUE_CARRIER as string) ORDER BY count(UNIQUE_CARRIER) desc').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+---------------------+
# UNIQUE_CARRIER|count(UNIQUE_CARRIER)|
# +--------------+---------------------+
#             WN|              1168871|
#             AA|               633857|
#             OO|               597880|
#             MQ|               540494|
#             UA|               490002|
#             US|               485447|
#             DL|               475889|
#             XE|               434773|
#             NW|               414526|
#             CO|               323151|
#             YV|               294362|
#             EV|               286234|
#             FL|               263159|
# ...

# %%
display(spark.sql('select UNIQUE_CARRIER,COUNT(UNIQUE_CARRIER) as FREQUENCY,YEAR from Impact_Years_view group by UNIQUE_CARRIER,YEAR ORDER BY YEAR,COUNT(UNIQUE_CARRIER) DESC'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
spark.read.parquet("Impact_Years_view")
spark.read.parquet("After_Impact_view")

# %%
# %fs
rm -r /delta
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res4: Boolean = true
# </div>

# %%
dbutils.fs.ls("dbfs:/delta/Impact_years/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ExecutionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3243303568534590&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# ...

# %%
sqlContext.
